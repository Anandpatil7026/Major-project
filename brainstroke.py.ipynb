# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.26.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import pandas as pd

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('brain_stroke.xlsx')

# %%
df.shape
# Out:
# (4019, 11)

# %%
df.head(4020)
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4014  Female  70.0             1              1          Yes   Never_worked
# 4015    Male  45.0             0              0           No       Govt_job
# 4016  Female  65.0             0              0          Yes        Private
# 4017    Male  62.0             1              0           No        Private
# 4018    Male  12.0             0              0           No       children
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4014          Urban             155.00  30.2     never smoked       1
# 4015          Rural             125.20  24.2           smokes       0
# 4016          Urban             184.39  32.2           smokes       0
# 4017          Urban             148.25  25.0     never smoked       1
# 4018          Urban              84.20  16.2     never smoked       0
#
# [4019 rows x 11 columns]

# %%
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('brain_stroke.xlsx')

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.26.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('brain_stroke.xlsx')

# %%
df.shape
# Out:
# (4019, 11)

# %%
df.head(15)
# Out:
#     gender   age  hypertension  heart_disease ever_married      work_type  \
# 0     Male  67.0             0              1          Yes        Private
# 1     Male  80.0             0              1          Yes        Private
# 2   Female  49.0             0              0          Yes        Private
# 3   Female  79.0             1              0          Yes  Self-employed
# 4     Male  81.0             0              0          Yes        Private
# 5     Male  74.0             1              1          Yes        Private
# 6   Female  69.0             0              0           No        Private
# 7   Female  78.0             0              0          Yes        Private
# 8   Female  81.0             1              0          Yes        Private
# 9   Female  61.0             0              1          Yes       Govt_job
# 10  Female  54.0             0              0          Yes        Private
# 11  Female  79.0             0              1          Yes        Private
# 12  Female  50.0             1              0          Yes  Self-employed
# 13    Male  64.0             0              1          Yes        Private
# 14    Male  75.0             1              0          Yes        Private
#
#    Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0           Urban             228.69  36.6  formerly smoked       1
# 1           Rural             105.92  32.5     never smoked       1
# 2           Urban             171.23  34.4           smokes       1
# 3           Rural             174.12  24.0     never smoked       1
# 4           Urban             186.21  29.0  formerly smoked       1
# 5           Rural              70.09  27.4     never smoked       1
# 6           Urban              94.39  22.8     never smoked       1
# 7           Urban              58.57  24.2          Unknown       1
# 8           Rural              80.43  29.7     never smoked       1
# 9           Rural             120.46  36.8           smokes       1
# 10          Urban             104.51  27.3           smokes       1
# 11          Urban             214.09  28.2     never smoked       1
# 12          Rural             167.41  30.9     never smoked       1
# 13          Urban             191.61  37.5           smokes       1
# 14          Urban             221.29  25.8           smokes       1

# %%
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
a = df.isnull().mean()*100
print(a)
# Out:
# gender               0.0
# age                  0.0
# hypertension         0.0
# heart_disease        0.0
# ever_married         0.0
# work_type            0.0
# Residence_type       0.0
# avg_glucose_level    0.0
# bmi                  0.0
# smoking_status       0.0
# stroke               0.0
# dtype: float64

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4019.000000   4019.000000    4019.000000        4019.000000
# mean     43.470127      0.096293       0.057477         105.508694
# std      22.628759      0.295029       0.232781          44.289898
# min       0.080000      0.000000       0.000000          55.220000
# 25%      26.000000      0.000000       0.000000          77.295000
# 50%      45.000000      0.000000       0.000000          92.040000
# 75%      61.000000      0.000000       0.000000         114.195000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4019.000000  4019.000000
# mean     28.453949     0.053994
# std       6.861670     0.226033
# min      14.100000     0.000000
# 25%      23.500000     0.000000
# 50%      27.900000     0.000000
# 75%      32.700000     0.000000
# max      48.900000     1.000000

# %%
th1 = df.fillna(df.mean(numeric_only=True))

# %%
th1.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
th1.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
a = th1.nunique()
print(a)
# Out:
# gender                  2
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# avg_glucose_level    3313
# bmi                   334
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
for column in df.columns:
    unique_values = th1[column].value_counts()
    print(f"Column: {column}")
    print(unique_values)
    print()
# Out:
# Column: gender
# gender
# Female    2339
# Male      1680
# Name: count, dtype: int64
#
# Column: age
# age
# 78.00    79
# 57.00    78
# 50.00    72
# 52.00    71
# 53.00    70
#          ..
# 0.72      2
# 0.08      2
# 0.40      1
# 0.16      1
# 0.48      1
# Name: count, Length: 104, dtype: int64
#
# Column: hypertension
# hypertension
# 0    3632
# 1     387
# Name: count, dtype: int64
#
# Column: heart_disease
# heart_disease
# 0    3788
# 1     231
# Name: count, dtype: int64
#
# Column: ever_married
# ever_married
# Yes    2658
# No     1361
# Name: count, dtype: int64
#
# Column: work_type
# work_type
# Private          2314
# Self-employed     648
# children          544
# Govt_job          509
# Never_worked        4
# Name: count, dtype: int64
#
# Column: Residence_type
# Residence_type
# Urban    2028
# Rural    1991
# Name: count, dtype: int64
#
# Column: avg_glucose_level
# avg_glucose_level
# 93.88     5
# 91.85     5
# 85.84     4
# 77.67     4
# 83.16     4
#          ..
# 144.23    1
# 110.60    1
# 227.51    1
# 201.01    1
# 148.25    1
# Name: count, Length: 3313, dtype: int64
#
# Column: bmi
# bmi
# 28.70    34
# 27.60    33
# 27.70    33
# 26.70    33
# 27.00    31
#          ..
# 40.60     1
# 47.80     1
# 44.10     1
# 48.40     1
# 17.52     1
# Name: count, Length: 334, dtype: int64
#
# Column: smoking_status
# smoking_status
# never smoked       1501
# Unknown            1207
# formerly smoked     685
# smokes              626
# Name: count, dtype: int64
#
# Column: stroke
# stroke
# 0    3802
# 1     217
# Name: count, dtype: int64

# %%
a = pd.get_dummies(th1)
a.head(15)
# Out:
#      age  hypertension  heart_disease  avg_glucose_level   bmi  stroke  \
# 0   67.0             0              1             228.69  36.6       1
# 1   80.0             0              1             105.92  32.5       1
# 2   49.0             0              0             171.23  34.4       1
# 3   79.0             1              0             174.12  24.0       1
# 4   81.0             0              0             186.21  29.0       1
# 5   74.0             1              1              70.09  27.4       1
# 6   69.0             0              0              94.39  22.8       1
# 7   78.0             0              0              58.57  24.2       1
# 8   81.0             1              0              80.43  29.7       1
# 9   61.0             0              1             120.46  36.8       1
# 10  54.0             0              0             104.51  27.3       1
# 11  79.0             0              1             214.09  28.2       1
# 12  50.0             1              0             167.41  30.9       1
# 13  64.0             0              1             191.61  37.5       1
# 14  75.0             1              0             221.29  25.8       1
#
#     gender_Female  gender_Male  ever_married_No  ever_married_Yes  ...  \
# 0           False         True            False              True  ...
# 1           False         True            False              True  ...
# 2            True        False            False              True  ...
# 3            True        False            False              True  ...
# 4           False         True            False              True  ...
# 5           False         True            False              True  ...
# 6            True        False             True             False  ...
# 7            True        False            False              True  ...
# 8            True        False            False              True  ...
# 9            True        False            False              True  ...
# 10           True        False            False              True  ...
# 11           True        False            False              True  ...
# 12           True        False            False              True  ...
# 13          False         True            False              True  ...
# 14          False         True            False              True  ...
#
#     work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                    False               True                    False
# 1                    False               True                    False
# 2                    False               True                    False
# 3                    False              False                     True
# 4                    False               True                    False
# 5                    False               True                    False
# 6                    False               True                    False
# 7                    False               True                    False
# 8                    False               True                    False
# 9                    False              False                    False
# 10                   False               True                    False
# 11                   False               True                    False
# 12                   False              False                     True
# 13                   False               True                    False
# 14                   False               True                    False
#
#     work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 0                False                 False                  True
# 1                False                  True                 False
# 2                False                 False                  True
# 3                False                  True                 False
# 4                False                 False                  True
# 5                False                  True                 False
# 6                False                 False                  True
# 7                False                 False                  True
# 8                False                  True                 False
# 9                False                  True                 False
# 10               False                 False                  True
# 11               False                 False                  True
# 12               False                  True                 False
# 13               False                 False                  True
# 14               False                 False                  True
#
#     smoking_status_Unknown  smoking_status_formerly smoked  \
# 0                    False                            True
# 1                    False                           False
# 2                    False                           False
# 3                    False                           False
# 4                    False                            True
# 5                    False                           False
# 6                    False                           False
# 7                     True                           False
# 8                    False                           False
# 9                    False                           False
# 10                   False                           False
# 11                   False                           False
# 12                   False                           False
# 13                   False                           False
# 14                   False                           False
#
#     smoking_status_never smoked  smoking_status_smokes
# 0                         False                  False
# 1                          True                  False
# 2                         False                   True
# 3                          True                  False
# 4                         False                  False
# 5                          True                  False
# 6                          True                  False
# 7                         False                  False
# 8                          True                  False
# 9                         False                   True
# 10                        False                   True
# 11                         True                  False
# 12                         True                  False
# 13                        False                   True
# 14                        False                   True
#
# [15 rows x 21 columns]

# %%
plt.figure(figsize=(10, 8))
hm1 = sns.heatmap(a.corr(), cmap='coolwarm', linewidths=.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.histplot(data=th1, x='gender', hue='stroke', multiple='stack', bins=20, palette='viridis', kde=True)
plt.title('Histogram of Age Grouped by Gender and Stroke')

total = len(th1['Residence_type'])
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height/total:.2%}', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.histplot(data=th1, x='ever_married', hue='stroke', multiple='stack', bins=20, palette='viridis', kde=True)


total = len(th1['Residence_type'])
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height/total:.2%}', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.histplot(data=th1, x='Residence_type', hue='stroke', multiple='stack', bins=20, palette='viridis', kde=True)


total = len(th1['Residence_type'])
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height/total:.2%}', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.histplot(data=th1, x='work_type', hue='stroke', multiple='stack', bins=20, palette='viridis', kde=True)

total = len(th1['Residence_type'])
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height/total:.2%}', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.histplot(data=th1, x='smoking_status', hue='stroke', multiple='stack', bins=20, palette='viridis', kde=True)

total = len(th1['Residence_type'])
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height/total:.2%}', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.show()

# %%
a.shape
# Out:
# (4019, 21)

# %%
a.columns
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'stroke', 'gender_Female', 'gender_Male', 'ever_married_No',
#        'ever_married_Yes', 'work_type_Govt_job', 'work_type_Never_worked',
#        'work_type_Private', 'work_type_Self-employed', 'work_type_children',
#        'Residence_type_Rural', 'Residence_type_Urban',
#        'smoking_status_Unknown', 'smoking_status_formerly smoked',
#        'smoking_status_never smoked', 'smoking_status_smokes'],
#       dtype='object')

# %%
X = a.drop(['stroke'], axis=1)
y = a['stroke']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=100)

# %%
X_train.columns
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'gender_Female', 'gender_Male', 'ever_married_No', 'ever_married_Yes',
#        'work_type_Govt_job', 'work_type_Never_worked', 'work_type_Private',
#        'work_type_Self-employed', 'work_type_children', 'Residence_type_Rural',
#        'Residence_type_Urban', 'smoking_status_Unknown',
#        'smoking_status_formerly smoked', 'smoking_status_never smoked',
#        'smoking_status_smokes'],
#       dtype='object')

# %%
X_train.shape, X_test.shape
# Out:
# ((2813, 20), (1206, 20))

# %%
y_train.shape, y_test.shape
# Out:
# ((2813,), (1206,))

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

# %%
sel = SelectFromModel(LogisticRegression(penalty="l1", C=10, solver='liblinear'))

# %%
sel.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=LogisticRegression(C=10, penalty='l1',
#                                              solver='liblinear'))

# %%
X_train1 = sel.transform(X_train)
X_test1 = sel.transform(X_test)

# %%
sel.get_feature_names_out()
# Out:
# array(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'gender_Female', 'gender_Male', 'ever_married_No',
#        'ever_married_Yes', 'work_type_Govt_job', 'work_type_Never_worked',
#        'work_type_Private', 'work_type_Self-employed',
#        'work_type_children', 'Residence_type_Rural',
#        'Residence_type_Urban', 'smoking_status_Unknown',
#        'smoking_status_formerly smoked', 'smoking_status_never smoked',
#        'smoking_status_smokes'], dtype=object)

# %%
X_train1.shape, X_train.shape
# X_train1
# Out:
# array([[58.  ,  0.  ,  0.  , ...,  0.  ,  1.  ,  0.  ],
#        [ 1.24,  0.  ,  0.  , ...,  0.  ,  0.  ,  0.  ],
#        [50.  ,  0.  ,  0.  , ...,  1.  ,  0.  ,  0.  ],
#        ...,
#        [11.  ,  0.  ,  0.  , ...,  0.  ,  0.  ,  0.  ],
#        [41.  ,  0.  ,  0.  , ...,  1.  ,  0.  ,  0.  ],
#        [62.  ,  1.  ,  0.  , ...,  1.  ,  0.  ,  0.  ]])

# %%
glm = LogisticRegression()
glm.fit(X_train1, y_train)
# Out:
# c:\Users\Anand\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = glm.predict(X_test1)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(y_test, y_pred)

# %%
print(f'Predict: {acc*100}%')
# Out:
# Predict: 94.94195688225538%

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from imblearn) (0.12.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.26.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.5.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anand\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('brain_stroke.xlsx')

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority')
X=df.drop(['stroke'],axis=1)
y=df['stroke']
X_over, y_over = oversample.fit_resample(X, y)




from sklearn.preprocessing import StandardScaler
s = StandardScaler()
df[['bmi', 'avg_glucose_level', 'age']] = s.fit_transform(df[['bmi', 'avg_glucose_level', 'age']])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size= 0.20, random_state= 42)

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size= 0.20, random_state= 42)

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority')
X=df.drop(['stroke'],axis=1)
y=df['stroke']
X_over, y_over = oversample.fit_resample(X, y)




from sklearn.preprocessing import StandardScaler
s = StandardScaler()
df[['bmi', 'avg_glucose_level', 'age']] = s.fit_transform(df[['bmi', 'avg_glucose_level', 'age']])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier

# Assuming X_train contains the categorical variable
# Apply One-Hot Encoding
encoder = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')
  # drop='first' avoids multicollinearity
X_train_encoded = encoder.fit_transform(X_train)
X_test_encoded = encoder.transform(X_test)

# Now fit the model
knn = KNeighborsClassifier(n_neighbors=11)
knn.fit(X_train_encoded, y_train)

# Predict and calculate probabilities
y_pred_knn = knn.predict(X_test_encoded)
y_pred_prob_knn = knn.predict_proba(X_test_encoded)[:, 1]
# Out:
# c:\Users\Anand\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [7, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')
 
X_train_encoded = encoder.fit_transform(X_train)
X_test_encoded = encoder.transform(X_test)

# Now fit the model
knn = KNeighborsClassifier(n_neighbors=11)
knn.fit(X_train_encoded, y_train)

# Predict and calculate probabilities
y_pred_knn = knn.predict(X_test_encoded)
y_pred_prob_knn = knn.predict_proba(X_test_encoded)[:, 1]
# Out:
# c:\Users\Anand\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [7, 8] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
#decision tree

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import imblearn as ib
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('brain_stroke.xlsx')

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4019 entries, 0 to 4018
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4019 non-null   object
#  1   age                4019 non-null   float64
#  2   hypertension       4019 non-null   int64
#  3   heart_disease      4019 non-null   int64
#  4   ever_married       4019 non-null   object
#  5   work_type          4019 non-null   object
#  6   Residence_type     4019 non-null   object
#  7   avg_glucose_level  4019 non-null   float64
#  8   bmi                4019 non-null   float64
#  9   smoking_status     4019 non-null   object
#  10  stroke             4019 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 345.5+ KB

# %%
df['bmi'].fillna(df['bmi'].mean(),inplace=True)

# %%
df[['hypertension', 'heart_disease', 'stroke']] = df[['hypertension', 'heart_disease', 'stroke']].astype(str)
# df = pd.get_dummies(df, drop_first= True)

# %%
df.head()
# Out:
#    gender   age hypertension heart_disease ever_married      work_type  \
# 0    Male  67.0            0             1          Yes        Private
# 1    Male  80.0            0             1          Yes        Private
# 2  Female  49.0            0             0          Yes        Private
# 3  Female  79.0            1             0          Yes  Self-employed
# 4    Male  81.0            0             0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status stroke
# 0          Urban             228.69  36.6  formerly smoked      1
# 1          Rural             105.92  32.5     never smoked      1
# 2          Urban             171.23  34.4           smokes      1
# 3          Rural             174.12  24.0     never smoked      1
# 4          Urban             186.21  29.0  formerly smoked      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4019 entries, 0 to 4018
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4019 non-null   object
#  1   age                4019 non-null   float64
#  2   hypertension       4019 non-null   object
#  3   heart_disease      4019 non-null   object
#  4   ever_married       4019 non-null   object
#  5   work_type          4019 non-null   object
#  6   Residence_type     4019 non-null   object
#  7   avg_glucose_level  4019 non-null   float64
#  8   bmi                4019 non-null   float64
#  9   smoking_status     4019 non-null   object
#  10  stroke             4019 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 345.5+ KB

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority')
X=df.drop(['stroke'],axis=1)
y=df['stroke']
X_over, y_over = oversample.fit_resample(X, y)

# %%
from sklearn.preprocessing import StandardScaler
s = StandardScaler()
df[['bmi', 'avg_glucose_level', 'age']] = s.fit_transform(df[['bmi', 'avg_glucose_level', 'age']])
df.head()
# Out:
#    gender       age hypertension heart_disease ever_married      work_type  \
# 0    Male  1.039951            0             1          Yes        Private
# 1    Male  1.614513            0             1          Yes        Private
# 2  Female  0.244404            0             0          Yes        Private
# 3  Female  1.570316            1             0          Yes  Self-employed
# 4    Male  1.658710            0             0          Yes        Private
#
#   Residence_type  avg_glucose_level       bmi   smoking_status stroke
# 0          Urban           2.781597  1.187330  formerly smoked      1
# 1          Rural           0.009288  0.589733     never smoked      1
# 2          Urban           1.484074  0.866668           smokes      1
# 3          Rural           1.549334 -0.649186     never smoked      1
# 4          Urban           1.822342  0.079590  formerly smoked      1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size= 0.20, random_state= 42)

# %%
print('X_train:', X_train.shape)
print('y_train:', y_train.shape)
print('X_test:', X_test.shape)
print('y_test:', y_test.shape)
# Out:
# X_train: (6083, 10)
# y_train: (6083,)
# X_test: (1521, 10)
# y_test: (1521,)

# %%
#decision tree
df.astype
# Out:
# <bound method NDFrame.astype of       gender       age hypertension heart_disease ever_married      work_type  \
# 0       Male  1.039951            0             1          Yes        Private
# 1       Male  1.614513            0             1          Yes        Private
# 2     Female  0.244404            0             0          Yes        Private
# 3     Female  1.570316            1             0          Yes  Self-employed
# 4       Male  1.658710            0             0          Yes        Private
# ...      ...       ...          ...           ...          ...            ...
# 4014  Female  1.172542            1             1          Yes   Never_worked
# 4015    Male  0.067616            0             0           No       Govt_job
# 4016  Female  0.951557            0             0          Yes        Private
# 4017    Male  0.818966            1             0           No        Private
# 4018    Male -1.390887            0             0           No       children
#
#      Residence_type  avg_glucose_level       bmi   smoking_status stroke
# 0             Urban           2.781597  1.187330  formerly smoked      1
# 1             Rural           0.009288  0.589733     never smoked      1
# 2             Urban           1.484074  0.866668           smokes      1
# 3             Rural           1.549334 -0.649186     never smoked      1
# 4             Urban           1.822342  0.079590  formerly smoked      1
# ...             ...                ...       ...              ...    ...
# 4014          Urban           1.117579  0.254496     never smoked      1
# 4015          Rural           0.444656 -0.620035           smokes      0
# 4016          Urban           1.781244  0.546007           smokes      0
# 4017          Urban           0.965155 -0.503431     never smoked      1
# 4018          Urban          -0.481178 -1.786077     never smoked      0
#
# [4019 rows x 11 columns]>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics 
from sklearn.metrics import accuracy_score
clf = DecisionTreeClassifier(max_depth=8)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
y_pred_train = clf.predict(X_train)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18660\1470433104.py in ?()
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 from sklearn import metrics
#       3 from sklearn.metrics import accuracy_score
#       4 clf = DecisionTreeClassifier(max_depth=8)
# ----> 5 clf = clf.fit(X_train,y_train)
#       6 y_pred = clf.predict(X_test)
#       7 y_pred_train = clf.predict(X_train)
#       8 print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
#
# c:\Users\Anand\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Anand\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
#    1005         self : DecisionTreeClassifier
#    1006             Fitted estimator.
#    1007         """
#    1008
# -> 1009         super()._fit(
#    1010             X,
#    1011             y,
#    1012             sample_weight=sample_weight,
#
# c:\Users\Anand\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     248             check_X_params = dict(
#     249                 dtype=DTYPE, accept_sparse="csc", force_all_finite=False
#     250             )
#     251             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 252             X, y = self._validate_data(
#     253                 X, y, validate_separately=(check_X_params, check_y_params)
#     254             )
#     255
#
# c:\Users\Anand\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     641                 # :(
#     642                 check_X_params, check_y_params = validate_separately
#     643                 if "estimator" not in check_X_params:
#     644                     check_X_params = {**default_check_params, **check_X_params}
# --> 645                 X = check_array(X, input_name="X", **check_X_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#
# c:\Users\Anand\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1004                         )
#    1005                     array = xp.astype(array, dtype, copy=False)
#    1006                 else:
#    1007                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1008             except ComplexWarning as complex_warning:
#    1009                 raise ValueError(
#    1010                     "Complex data not supported\n{}\n".format(array)
#    1011                 ) from complex_warning
#
# c:\Users\Anand\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     742         # Use NumPy API to support order
#     743         if copy is True:
#     744             array = numpy.array(array, order=order, dtype=dtype)
#     745         else:
# --> 746             array = numpy.asarray(array, order=order, dtype=dtype)
#     747
#     748         # At this point array is a NumPy ndarray. We convert it to an array
#     749         # container that is consistent with the input's namespace.
#
# c:\Users\Anand\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Female'

# %%
print('Training Accuracy:', accuracy_score(y_train, y_pred_train))
print('Testing Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Training Accuracy: 0.8827880979779714
# Testing Accuracy: 0.8553583168967784

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=clf.classes_)
disp.plot()
plt.show()
precision = precision_score(y_test, y_pred)
print("Precision:", precision)
recall = recall_score(y_test, y_pred)
print("Recall:", recall)
f1 = f1_score(y_test, y_pred)
print("F1 Score:", f1)
# Out:
# Precision: 0.824969400244798
# Recall: 0.8974700399467377
# F1 Score: 0.8596938775510204

# %%
#RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score
rf_clf = RandomForestClassifier(n_estimators = 10,max_depth=9)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)
y_pred_train = rf_clf.predict(X_train)
print('Accuracy:', metrics.accuracy_score(y_test, y_pred_rf))

rf_clf = RandomForestClassifier(n_estimators=10, max_depth=9)
rf_clf.fit(X_train, y_train)

y_pred_rf = rf_clf.predict(X_test)
y_pred_train = rf_clf.predict(X_train)
print('Accuracy:', accuracy_score(y_test, y_pred_rf))
# Out:
# Accuracy: 0.9040105193951348
# Accuracy: 0.8987508218277449

# %%
print('Training Accuracy:', accuracy_score(y_train, y_pred_train))
print('Testing Accuracy:', accuracy_score(y_test, y_pred_rf))
# Out:
# Training Accuracy: 0.9232286700641131
# Testing Accuracy: 0.8987508218277449

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, y_pred_rf, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=clf.classes_)
disp.plot()
plt.show()

precision = precision_score(y_test, y_pred_rf)
print("Precision:", precision)

recall = recall_score(y_test, y_pred_rf)
print("Recall:", recall)

f1 = f1_score(y_test, y_pred_rf)
print("F1 Score:", f1)
# Out:
# Precision: 0.8653610771113831
# Recall: 0.9414114513981359
# F1 Score: 0.9017857142857143

# %%
#KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
from sklearn.metrics import auc,roc_auc_score,roc_curve,precision_score,recall_score,f1_score

knn = KNeighborsClassifier(n_neighbors = 11)
knn.fit(X_train,y_train)
y_pred_knn = knn.predict(X_test)
y_pred_prob_knn = knn.predict_proba(X_test)[:, 1]

confusion_matrix(y_test, y_pred_knn)
print('Accuracy:',accuracy_score(y_test, y_pred_knn))
print('ROC AUC Score:', roc_auc_score(y_test, y_pred_prob_knn))
# Out:
# Accuracy: 0.8757396449704142
# ROC AUC Score: 0.9619295484808135

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_pred_knn, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=clf.classes_)
disp.plot()
plt.show()
roc_auc = roc_auc_score(y_test, y_pred_prob_knn)
print('ROC AUC Score:', roc_auc)

precision = precision_score(y_test, y_pred_knn)
print("Precision:", precision)

recall = recall_score(y_test, y_pred_knn)
print("Recall:", recall)

f1 = f1_score(y_test, y_pred_knn)
print("F1 Score:", f1)
# Out:
# ROC AUC Score: 0.9619295484808135
# Precision: 0.798936170212766
# Recall: 1.0
# F1 Score: 0.8882318154937907

# %%
#TESTING
age=67
avg_glucose_level=228.69
bmi=36.6
gender_Male=1
hypertension=0
heart_disease=1
ever_married_Yes=1
work_type_Private=1
work_type_Self_employed=0	
work_type_Retired=0
work_type_children=0
Residence_type_Urban=1
smoking_status_formerly_smoked=1
smoking_status_never_smoked=0
smoking_status_smokes=0
input_features = [age, avg_glucose_level, bmi, gender_Male, hypertension, heart_disease, 
                  ever_married_Yes, work_type_Private, work_type_Self_employed,work_type_Retired, work_type_children,
                  Residence_type_Urban, smoking_status_formerly_smoked, smoking_status_never_smoked, 
                  smoking_status_smokes]
                  
features_value = [np.array(input_features)]
features_name = ['age', 'avg_glucose_level', 'bmi', 'gender_Male', 'hypertension', 
                 'heart_disease', 'ever_married_Yes', 'work_type_Private', 
                 'work_type_Self_employed','work_type_Retired', 'work_type_children', 'Residence_type_Urban', 
                 'smoking_status_formerly_smoked', 'smoking_status_never_smoked', 'smoking_status_smokes']

# Ensure the feature names are exactly the same as in X_train
df = pd.DataFrame(features_value, columns=X_train.columns)

# Prediction for the new individual
prediction = rf_clf.predict(df)[0]
print(prediction)
# Out:
# True

# %%
print("Length of input_features:", len(input_features))
# Out:
# Length of input_features: 15

# %%
from sklearn.ensemble import RandomForestClassifier

# Assuming X_train, y_train are your training data
rf_clf = RandomForestClassifier(random_state=42)
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
import pickle
model_path="C:/Users/Anand/Anand1.pkl"
with open(model_path,'wb') as f:
    pickle.dump(rf_clf,f)

print("Model saved succesfully at:",model_path)
# Out:
# Model saved succesfully at: C:/Users/Anand/Anand1.pkl
